# %% [markdown]
# # Config

# %%
from datetime import datetime
from pytz import UTC # timezone
import time
import numpy as np
import pandas as pd
from pandas import read_excel
import matplotlib.pyplot as plt

import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

def TEXT_TO_FILE(filename, encoding):
    encoding = 'utf-8' if len(encoding) == 0 else encoding
    with io.open(filename, 'w', encoding=encoding) as f:
        f.write(x)
        f.close()

def DF_TO_EXCEL(df, filename, sheet_name):
    sheet_name = 'Sheet1' if len(sheet_name) == 0 else sheet_name
    writer = pd.ExcelWriter(filename)
    df.to_excel(writer, sheet_name)
    writer.save()
    
def DF_TO_EXCEL_MUL(dfs, filename):
    writer = pd.ExcelWriter(filename, engine='xlsxwriter')
    for sheetname, df in dfs.items():  # loop through `dict` of dataframes
        df.to_excel(writer, sheet_name=sheetname)  # send df to writer
        worksheet = writer.sheets[sheetname]  # pull worksheet object
        for idx, col in enumerate(df):  # loop through all columns
            series = df[col]
            max_len = max((
                series.astype(str).map(len).max(),  # len of largest item
                len(str(series.name))  # len of column name/header
                )) + 1  # adding a little extra space
            worksheet.set_column(idx, idx, max_len)  # set column width
    writer.save()
    
def convertMillis(millis):
    seconds=(millis/1000)%60
    minutes=(millis/(1000*60))%60
    hours=(millis/(1000*60*60))%24
    return int(seconds), int(minutes), int(hours)

def data_to_pandas(pair_data):
    # Create pandas data frame and clean/format data
    names = ['time', 'open', 'close', 'high', 'low', 'volume']
    df = pd.DataFrame(pair_data, columns=names)
    df.drop_duplicates(inplace=True)
    df['time'] = pd.to_datetime(df['time'], unit='ms')
    df.set_index('time', inplace=True)
    df.sort_index(inplace=True)
    return df

def fetch_data(start, stop, symbol, interval, tick_limit, step):
    # Create api instance
    api_v2 = bitfinex.bitfinex_v2.api_v2(key, secrete)
    data = []
    start = start - step
    while start < stop:
        start = start + step
        end = start + step
        res = api_v2.candles(symbol=symbol, interval=interval,
                             limit=tick_limit, start=start,
                             end=end)
        data.extend(res)
        time.sleep(1)
    return data

# %% [markdown]
# # bitfinex Check account

# %% [raw]
# # https://medium.com/coinmonks/how-to-get-historical-crypto-currency-data-954062d40d2d

# %%
import bitfinex

key = 'nMF9GtDIyG4UZwJwWuANFPLfyypBB5OCxRsfJmICI1D'
secrete = 'cPoOvoQA9kYsTtjxVn3eM002ePG9GupTDAp4In479j1'

# Create api instance of the v2 API
api_v2 = bitfinex.bitfinex_v2.api_v2(key, secrete)

# %% [markdown]
# # Fetch data from bitfinex

# %% [markdown]
# ## Fetch data V.1@1st Time

# %%
from datetime import datetime
import time

# Define query parameters
pair = 'btcusd' # Currency pair of interest
bin_size = '5m' # This will return minute data
limit = 5000    # We want the maximum of 1000 data points 
# Set step size
time_step = limit * 5*60*1000 # x bin_size

# Define the start date 
t_start = datetime(2019, 1, 1, 0, 0)
t_start = time.mktime(t_start.timetuple()) * 1000

# Define the end date
t_stop = datetime(2019, 7, 16, 0, 0)
t_stop = time.mktime(t_stop.timetuple()) * 1000

pair_data = fetch_data(start=t_start, stop=t_stop, symbol=pair,
                       interval=bin_size, tick_limit=limit, 
                       step=time_step)

last_index = pair_data.index('error') if pair_data.index('error') > 0 else len(pair_data)
df = data_to_pandas(pair_data[:last_index])
df.info()
# Out:
# 1546275600000.0
# 1547775600000.0
# 1549275600000.0
# 1550775600000.0
# 1552275600000.0
# 1553775600000.0
# 1555275600000.0
# 1556775600000.0
# 1558275600000.0
# 1559775600000.0
# 1561275600000.0
# 1562775600000.0
# 1564275600000.0
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 54810 entries, 2018-12-31 17:00:00 to 2019-07-10 16:20:00
# Data columns (total 5 columns):
# open      54810 non-null float64
# close     54810 non-null float64
# high      54810 non-null float64
# low       54810 non-null float64
# volume    54810 non-null float64
# dtypes: float64(5)
# memory usage: 2.5 MB

# %% [markdown]
# ## Load Old data from Excel

# %%
pair = 'btcusd'
path = 'data'
filename = '{}/{}_5m.xlsx'.format(path, pair)
sheet_name = pair
df = pd.read_excel(filename, sheet_name=sheet_name, index_col='time')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56515 entries, 2018-12-31 17:00:00 to 2019-07-16 17:00:00
# Data columns (total 8 columns):
# open       56515 non-null float64
# close      56515 non-null float64
# high       56515 non-null float64
# low        56515 non-null float64
# volume     56515 non-null float64
# atr        56515 non-null float64
# atr_sma    56515 non-null float64
# zone       56515 non-null int64
# dtypes: float64(7), int64(1)
# memory usage: 3.9 MB

# %% [markdown]
# ## Custom fetch Data

# %%
import bitfinex

key = 'nMF9GtDIyG4UZwJwWuANFPLfyypBB5OCxRsfJmICI1D'
secrete = 'cPoOvoQA9kYsTtjxVn3eM002ePG9GupTDAp4In479j1'

# Create api instance of the v2 API
api_v2 = bitfinex.bitfinex_v2.api_v2(key, secrete)

# %%
import datetime
import time

# Define query parameters
pair = 'btcusd' # Currency pair of interest
bin_size = '5m' # This will return minute data
limit = 5000    # We want the maximum of 1000 data points 
# Define the start date
t_start = datetime.datetime(2019, 7, 16, 0, 0)
t_start = time.mktime(t_start.timetuple()) * 1000
# Define the end date
t_stop = datetime.datetime(2019, 7, 19, 0, 0)
t_stop = time.mktime(t_stop.timetuple()) * 1000
pair_data1= api_v2.candles(symbol=pair, interval=bin_size,  
                        limit=limit, start=t_start, end=t_stop)
df1 = data_to_pandas(pair_data1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 706 entries, 2019-07-15 17:00:00 to 2019-07-18 03:45:00
# Data columns (total 5 columns):
# open      706 non-null float64
# close     706 non-null float64
# high      706 non-null float64
# low       706 non-null float64
# volume    706 non-null float64
# dtypes: float64(5)
# memory usage: 33.1 KB

# %%
df1['atr'] = 0
df1['atr_sma'] = 0
df1['zone'] = 0
df1 = df1[['open', 'close', 'high', 'low', 'volume', 'atr', 'atr_sma', 'zone']]
df1.info()

# %%
end_date = df[-1:].index.values[0]
end_date
# Out:
# numpy.datetime64('2019-07-16T17:00:00.000000000')

# %%
df1 = df1.loc[df1.index > end_date]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 417 entries, 2019-07-16 17:05:00 to 2019-07-18 03:45:00
# Data columns (total 8 columns):
# open       417 non-null float64
# close      417 non-null float64
# high       417 non-null float64
# low        417 non-null float64
# volume     417 non-null float64
# atr        417 non-null int64
# atr_sma    417 non-null int64
# zone       417 non-null int64
# dtypes: float64(5), int64(3)
# memory usage: 29.3 KB

# %% [markdown]
# # Convert to pandas

# %%
df_excel = df.copy()

# %%
# merge data
frames = [df_excel, df1]
_df = pd.concat(frames)
df = _df.copy()
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56932 entries, 2018-12-31 17:00:00 to 2019-07-18 03:45:00
# Data columns (total 8 columns):
# open       56932 non-null float64
# close      56932 non-null float64
# high       56932 non-null float64
# low        56932 non-null float64
# volume     56932 non-null float64
# atr        56932 non-null float64
# atr_sma    56932 non-null float64
# zone       56932 non-null int64
# dtypes: float64(7), int64(1)
# memory usage: 3.9 MB

# %% [markdown]
# ## Calculate Zone

# %%
zone_len = 500 #btc
df['zone'] = df['close'].apply(lambda x: (x - (x%zone_len) ))
df_time_in_the_zone = df.groupby('zone').count()[['close']]

df_time_in_the_zone.rename(columns={'close': 'count_point'}, inplace=True)

df_time_in_the_zone['time_sec'] = df_time_in_the_zone['count_point'] * 5 * 60 #piont * 5min * 60sec
df_time_in_the_zone['str_time'] = df_time_in_the_zone['time_sec'].apply(lambda x: str(datetime.timedelta(seconds=x)))
df_time_in_the_zone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 22 entries, 3000.0 to 13500.0
# Data columns (total 3 columns):
# count_point    22 non-null int64
# time_sec       22 non-null int64
# str_time       22 non-null object
# dtypes: int64(2), object(1)
# memory usage: 704.0+ bytes

# %% [markdown]
# ## Calculate ATR

# %%
import talib as ta

timeperiod = 14

high = df.high.values
low = df.low.values
close = df.close.values

atr = ta.ATR(high, low, close, timeperiod=timeperiod)
atr_sma = ta.SMA(atr, timeperiod)
atr_sma[0:timeperiod] = 0
atr[0:timeperiod] = 0
df['atr'] = atr
df['atr_sma'] = atr_sma

df = df.fillna(0)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56932 entries, 2018-12-31 17:00:00 to 2019-07-18 03:45:00
# Data columns (total 8 columns):
# open       56932 non-null float64
# close      56932 non-null float64
# high       56932 non-null float64
# low        56932 non-null float64
# volume     56932 non-null float64
# atr        56932 non-null float64
# atr_sma    56932 non-null float64
# zone       56932 non-null float64
# dtypes: float64(8)
# memory usage: 3.9 MB

# %%
list(df)
# Out:
# ['open', 'close', 'high', 'low', 'volume', 'atr', 'atr_sma', 'zone']

# %% [markdown]
# # Export to Excel

# %%
pair = 'btcusd'
path = 'data'
filename = '{}/{}_5m.xlsx'.format(path, pair)
sheet_name = pair
DF_TO_EXCEL(df, filename, sheet_name)
print(filename)
# Out:
# data/btcusd_5m.xlsx

# %% [markdown]
# # Analyzing time series data in Pandas

# %%
# https://medium.com/@andykashyap/top-5-tricks-to-make-plots-look-better-9f6e687c1e08
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

# %% [markdown]
# ## Plot

# %%
"""
xx-small
x-small
small
medium
large
x-large
xx-large
"""

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

date_start = df[0:1].index[0]
date_end = df[-1:].index[0]
price = df[-1:].close.values[0]
zone = df[-1:].zone.values[0]
atr = df[-1:].atr.values[0]

zone_len = 500 #btc

df['zone'] = df['close'].apply(lambda x: (x-(x%zone_len)))
df_time_in_the_zone = df.groupby('zone').count()[['close']]
df_time_in_the_zone.rename(columns={'close': 'count_point'}, inplace=True)
df_time_in_the_zone['time_sec'] = df_time_in_the_zone['count_point'] * 5 * 60 #point * 5min * 60sec
df_time_in_the_zone['str_time'] = df_time_in_the_zone['time_sec'].apply(lambda x: str(datetime.timedelta(seconds=x)))

fig, ax = plt.subplots(figsize=(15,6))

for idx,row in df_time_in_the_zone.iterrows():
    
    close = df.loc[df.zone == idx].close.values[0]
    close = close - (close%zone_len)
    cur_zone = '>> ATR:%s '%int(atr) if (price - (price%zone_len)) == close else ''
    label = '{}Z:{} T:{}'.format(cur_zone, str(int(idx)), row.str_time)
    
    x = df.loc[df.zone == idx].close.values
    y = df.loc[df.zone == idx].atr.values
    scale = 15
    
    ax.scatter(x, y, s=scale, label=label, alpha=0.3, edgecolors='white', cmap='Accent', marker="o")    
    
ax.legend(bbox_to_anchor=(1, 1), fontsize = 'large')
ax.grid(True)

plt.xlabel('close')
plt.ylabel('atr')
plt.title('BTCUSD 5Min from {} to {}@{} btc/usd zone:{} atr:{}'.format(date_start, date_end, price, int(zone), int(atr)))
plt.xticks(range(3000,15000,500))
plt.xticks(rotation=90)
plt.show()

# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

import datetime

date_start = df[0:1].index[0]
date_end = df[-1:].index[0]
price = df[-1:].close.values[0]
zone = df[-1:].zone.values[0]
atr = df[-1:].atr.values[0]

fig, ax = plt.subplots()
ax.scatter(x=df.close, y=df.atr, s = 4
            , alpha = 0.9, c=df.zone
            , cmap='Accent')
ax.legend(bbox_to_anchor=(1, 1), fontsize = 'medium')

plt.xlabel('close')
plt.ylabel('atr')
plt.title('BTCUSD 5Min from {} to {}@{} btc/usd zone:{} atr:{}'.format(date_start, date_end, price, int(zone), int(atr)))
plt.xticks(range(3000,15000,500))
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np

date_start = df[0:1].index[0]
date_end = df[-1:].index[0]
price = df[-1:].close.values[0]
zone = df[-1:].zone.values[0]
atr = df[-1:].atr.values[0]
ax = df.plot.scatter(figsize=(15,6),
               x='close', y='atr', c='zone', cmap='Accent',
               title = 'BTCUSD 5Min from {} to {}@{} btc/usd zone:{} atr:{}'.format(date_start, date_end, price, int(zone), int(atr)),
               logx = 'True',
               edgecolors='white',
               alpha=0.5,
               xticks=range(3500,15000,500))

# %%
ax = df.loc[:].plot.scatter(x='close',y='atr',c='zone',colormap='viridis')

# %% [markdown]
# ## Test seaborn

# %%
import seaborn as sns
import pandas as pd

sns.set(style="whitegrid", color_codes=True)

sns.pairplot(x_vars=["close"], y_vars=["atr"], data=df, hue="zone", height=10, markers="o", palette="husl")

# %%
g = sns.PairGrid(df, x_vars=["close"], y_vars=["atr"], hue="zone", height=10, palette="Set2")
g = g.map(plt.scatter, linewidths=1, edgecolor='w', s=10)
g = g.add_legend()

# %%
import matplotlib.pyplot as plt
import random

number_of_colors = len(df_time_in_the_zone.index.values)

colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

# %% [markdown]
# ## Test OHLC

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] =[12.0, 8.0]
from datetime import datetime
start_date = datetime(2019,4,1)
end_date = datetime(2019,7,31)
df['close'][(df.index >= start_date) & ( df.index <= end_date)].plot(grid=True)
#df['close'].loc[df['zone'] == 5].plot(grid=True)
#df['close'].loc[df['zone'] == 5].plot(kind='box', figsize=[16,8])

# %%
import statsmodels.api as sm
from datetime import datetime

start_date = datetime(2019,6,1)
end_date = datetime(2019,7,19)

data = df['close'][(df.index >= start_date) & ( df.index <= end_date)]
decomposition = sm.tsa.seasonal_decompose(data, freq=60*24, model = 'additive')
fig = decomposition.plot()
matplotlib.rcParams['figure.figsize'] = [9.0, 5.0]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
fig, ax = plt.subplots()
ax.grid(True)
year = mdates.YearLocator(month=1)
month = mdates.MonthLocator(interval=3)
year_format = mdates.DateFormatter('%Y')
month_format = mdates.DateFormatter('%m')
ax.xaxis.set_minor_locator(month)
ax.xaxis.grid(True, which = 'minor')
ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_format)
plt.plot(data.index, df['close'][(df.index >= start_date) & ( df.index <= end_date)], c='blue')
plt.plot(decomposition.trend.index, decomposition.trend, c='red')
